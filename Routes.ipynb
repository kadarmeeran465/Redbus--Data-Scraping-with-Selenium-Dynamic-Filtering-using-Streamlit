# %%
# importing all necessary modules
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.webdriver.support.wait import WebDriverWait
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
def scrape_All_RTC_Operator_info():
    driver = webdriver.Chrome()
    driver.get('https://www.redbus.in')
    gov_buses_button = driver.get("https://www.redbus.in/online-booking/rtc-directory")
    RTC_Operator_Directories =  driver.find_elements(By.CSS_SELECTOR,'a[class = "D113_link"]')
    RTC_Operator = [i.text for i in RTC_Operator_Directories]
    RTC_Operators_URL = [i.get_attribute('href') for i in RTC_Operator_Directories]
    return [item for item in RTC_Operator],RTC_Operators_URL

# %%
def scrape_routes(rtcurl):
    driver = webdriver.Chrome()
    driver.get(rtcurl)
    actions = ActionChains(driver)
    routes = []
    def extract_routes():
        all_routes = driver.find_elements(By.CLASS_NAME, "route")
        for route in all_routes:
            routes.append(route.text)
    try:
        WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.CLASS_NAME, 'route')))
        extract_routes()
        page_driver = driver.find_elements(By.CLASS_NAME, "DC_117_pageTabs")
        for i in range(1, len(page_driver)):
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable(page_driver[i]))
            actions.move_to_element(page_driver[i]).click().perform()
            WebDriverWait(driver, 10).until(EC.presence_of_all_elements_located((By.CLASS_NAME, 'route')))
            extract_routes()
    except Exception as e:
        driver.quit()
    finally:
        driver.quit()
    return route_names.append(routes)

# %%
RTC_Operators,RTC_Operators_URLs = scrape_All_RTC_Operator_info()

# %%
route_names = []
for i in RTC_Operators_URLs:
    scrape_routes123(i)

# %%
routeurl = [ 'https://www.redbus.in/online-booking/tnstc',
 'https://www.redbus.in/online-booking/ksrtc-kerala',
 'https://www.redbus.in/online-booking/ktcl',
 'https://www.redbus.in/online-booking/tsrtc']
route_names = []
for i in routeurl:
    scrape_routes123(i)

# %%
len(RTC_Operators)
# Out:
# 25

# %%
len(route_names)
# Out:
# 25

# %%
data = {"RTC_Names": RTC_Operators,"Route_Names": route_names}
data
# Out:
# {'RTC_Names': ['Bihar State Tourism Development Corporation (BSTDC)',
#   'West Bengal Transport Corporation',
#   'Bihar State Road Transport Corporation (BSRTC)',
#   'NORTH BENGAL STATE TRANSPORT CORPORATION',
#   'WBTC (CTC)',
#   'BSRTC Operated By VIP Travels',
#   'South Bengal State Transport Corporation (SBSTC)',
#   'Himachal Pradesh Tourism Development Corporation (HPTDC)',
#   'PEPSU (Punjab)',
#   'PEPSU (Punjab)',
#   'RSRTC',
#   'HRTC',
#   'UPSRTC',
#   'Chandigarh Transport Undertaking (CTU)',
#   'Puducherry Road Transport Corporation (PRTC)',
#   'TNSTC',
#   'KSRTC (Kerala)',
#   'Kadamba Transport Corporation Limited (KTCL)',
#   'TSRTC',
#   'APSRTC',
#   'Assam State Transport Corporation (ASTC)',
#   'KAAC TRANSPORT',
#   'Sikkim Nationalised Transport (SNT)',
#   'Meghalaya Transport Corporation(MTC)',
#   'GSRTC'],
#  'Route_Names': [[],
#   ['Kolkata to Digha',
#    'Digha to Kolkata',
#    'Mandarmani to Kolkata',
#    'Kolkata to Mandarmani',
# ...

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#                                             RTC_Names  \
# 0   Bihar State Tourism Development Corporation (B...
# 1                   West Bengal Transport Corporation
# 2      Bihar State Road Transport Corporation (BSRTC)
# 3            NORTH BENGAL STATE TRANSPORT CORPORATION
# 4                                          WBTC (CTC)
# 5                       BSRTC Operated By VIP Travels
# 6    South Bengal State Transport Corporation (SBSTC)
# 7   Himachal Pradesh Tourism Development Corporati...
# 8                                      PEPSU (Punjab)
# 9                                      PEPSU (Punjab)
# 10                                              RSRTC
# 11                                               HRTC
# 12                                             UPSRTC
# 13             Chandigarh Transport Undertaking (CTU)
# 14       Puducherry Road Transport Corporation (PRTC)
# 15                                              TNSTC
# ...

# %%
df1.to_csv('RTC_routes.csv', index=False)

# %%
route_data = pd.read_csv('RTC_routes.csv')
route_data
# Out:
#                                             RTC_Names  \
# 0   Bihar State Tourism Development Corporation (B...
# 1                   West Bengal Transport Corporation
# 2      Bihar State Road Transport Corporation (BSRTC)
# 3            NORTH BENGAL STATE TRANSPORT CORPORATION
# 4                                          WBTC (CTC)
# 5                       BSRTC Operated By VIP Travels
# 6    South Bengal State Transport Corporation (SBSTC)
# 7   Himachal Pradesh Tourism Development Corporati...
# 8                                      PEPSU (Punjab)
# 9                                      PEPSU (Punjab)
# 10                                              RSRTC
# 11                                               HRTC
# 12                                             UPSRTC
# 13             Chandigarh Transport Undertaking (CTU)
# 14       Puducherry Road Transport Corporation (PRTC)
# 15                                              TNSTC
# ...

# %%
from sqlalchemy import create_engine

database_url = 'mysql+pymysql://root:abcd123@127.0.0.1/red_bus'
engine = create_engine(database_url)

# %%
route_data.to_sql(name= "RTC_routes",con= engine,if_exists="replace",index= False)
# Out:
# C:\Users\SHAHUL JAMAL THEEN\AppData\Local\Temp\ipykernel_3648\397388523.py:1: UserWarning: The provided table name 'RTC_routes' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   route_data.to_sql(name= "RTC_routes",con= engine,if_exists="replace",index= False)
# 25

# %%
#data["Route Name"] = data["Route Name"].str.replace(r'\s*bus$','',regex=True)
data['Route Name'] = data['Route Name'].apply(lambda x: ' '.join(x.split()[:-1]))

# %%
# Remove the last word "bus" from every record in route_name column
data = data['Route Name'].str.replace(r'\s*bus$', '', regex=True)

# %%
data.to_csv('Redbus_Project1.csv', index=False)

# %%
# Function to get details for a particular route name
def get_route_details(route_name):
    # Filter the DataFrame for the given route name
    filtered_df = data[data['Route Name'] == route_name]
    
    # Check if the filtered DataFrame is not empty
    if not filtered_df.empty:
        return filtered_df
    else:
        return None

# %%
get_route_details('Gangtok to Siliguri')
# Out:
#           ID           Route Name  \
# 25271  25272  Gangtok to Siliguri
# 25272  25273  Gangtok to Siliguri
# 25273  25274  Gangtok to Siliguri
# 25274  25275  Gangtok to Siliguri
# 25275  25276  Gangtok to Siliguri
# 25276  25277  Gangtok to Siliguri
# 25277  25278  Gangtok to Siliguri
# 25278  25279  Gangtok to Siliguri
# 25279  25280  Gangtok to Siliguri
#
#                                               Route Link  \
# 25271  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25272  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25273  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25274  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25275  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25276  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25277  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25278  https://www.redbus.in/bus-tickets/gangtok-to-s...
# 25279  https://www.redbus.in/bus-tickets/gangtok-to-s...
#
# ...
